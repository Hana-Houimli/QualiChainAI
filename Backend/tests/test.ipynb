# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from rag.remote_llm import RemoteLLM
remote_llm = RemoteLLM(
    url="https://happening-colt-delouse.ngrok-free.dev/generate"
)

# %%
response=remote_llm.invoke("Bonjour")
print(response)
# Out:
# Bonjour! Comment puis-je vous aider aujourd'hui?

# %%
from rag.remote_chat_model import RemoteChatModel
chat_model = RemoteChatModel(remote_llm=remote_llm)

# %%
from core.dependencies import regulatory_agent

response = regulatory_agent.run(
    "Quelle est la procédure à suivre lorsqu'une température de stockage dépasse les limites autorisées ?"
)

print(response)
# Out:
# ...
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# ...
