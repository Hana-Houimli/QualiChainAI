# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from rag.config import *
from rag.vector_store import VectorStore
from rag.ingest_document import ingest_document

# %%
sop_vectordb = VectorStore(EMBEDDING_MODEL,collection_name="sop_documents", persist_directory="../storage/chroma_db")
# Out:
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]

# %%
documents = [
    r"C:\Users\Lenovo\Desktop\QualiChainAI\Backend\docs\sops_docs\SOP-QA-101_Surveillance_Temperature_Chaine_du_Froid.pdf",
    r"C:\Users\Lenovo\Desktop\QualiChainAI\Backend\docs\sops_docs\SOP-QA-102_Reception_Produits_Pharmaceutiques.pdf",
    r"C:\Users\Lenovo\Desktop\QualiChainAI\Backend\docs\sops_docs\SOP-QA-103_Gestion_Stockage_Produits_Pharmaceutiques.pdf",
    r"C:\Users\Lenovo\Desktop\QualiChainAI\Backend\docs\sops_docs\SOP-QA-104_Gestion_Excursions_Temperature.pdf",
    r"C:\Users\Lenovo\Desktop\QualiChainAI\Backend\docs\sops_docs\SOP-QA-105_Gestion_Rappels_de_Lots.pdf",
    r"C:\Users\Lenovo\Desktop\QualiChainAI\Backend\docs\sops_docs\SOP-QA-106_Gestion_Documentaire_Enregistrements.pdf",
    r"C:\Users\Lenovo\Desktop\QualiChainAI\Backend\docs\sops_docs\SOP-QA-107_Gestion_Formation_Personnel.pdf"
    
]
for doc in documents:

    result = ingest_document(sop_vectordb, doc,CHUNK_SIZE,CHUNK_OVERLAP)
    print(result)
# Out:
# {'message': 'Document successfully indexed.', 'pages': 5, 'chunks': 28}
# {'message': 'Document successfully indexed.', 'pages': 4, 'chunks': 23}
# {'message': 'Document successfully indexed.', 'pages': 5, 'chunks': 25}
# {'message': 'Document successfully indexed.', 'pages': 5, 'chunks': 24}
# {'message': 'Document successfully indexed.', 'pages': 5, 'chunks': 24}
# {'message': 'Document successfully indexed.', 'pages': 5, 'chunks': 24}
# {'message': 'Document successfully indexed.', 'pages': 4, 'chunks': 19}
