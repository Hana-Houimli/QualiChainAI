# %%
import sys
import os
import json
sys.path.append(os.path.abspath(".."))

from pymongo import MongoClient

# %%
client = MongoClient("mongodb://localhost:27017")

db = client["qualichainAI"]

collection = db["audit_checklists"]

folder_path =  r"C:\Users\Lenovo\Desktop\QualiChainAI\Backend\docs\audit_checklists"

for file in os.listdir(folder_path):

    if file.endswith(".json"):

        path = os.path.join(folder_path, file)

        with open(
            path,
            "r",
            encoding="utf-8"
        ) as f:

            data = json.load(f)

            collection.insert_one(data)

            print(
                f"{file} importé"
            )
# Out:
# audit_chaine_froid.json importé
# audit_distributeur.json importé
# audit_entrepot.json importé
# audit_fournisseur.json importé
# audit_reglementaire.json importé
# audit_systeme_qualite.json importé
# audit_transport.json importé

# %%
for checklist in collection.find():

    print(
        checklist["type_audit"]
    )
# Out:
# Audit chaîne du froid pharmaceutique
# Audit distributeur pharmaceutique
# Audit entrepôt de stockage pharmaceutique
# Audit fournisseur pharmaceutique
# Audit conformité réglementaire
# Audit système qualité
# Audit transport pharmaceutique
