# %%
import sys
import os
import json
sys.path.append(os.path.abspath(".."))

from pymongo import MongoClient

# %%
client = MongoClient("mongodb://localhost:27017")

db = client["qualichainAI"]

collection = db["audit_reports"]

folder_path =  r"C:\Users\Lenovo\Desktop\QualiChainAI\Backend\docs\audit_rapports"

for file in os.listdir(folder_path):

    if file.endswith(".json"):

        path = os.path.join(folder_path, file)

        with open(
            path,
            "r",
            encoding="utf-8"
        ) as f:

            data = json.load(f)

            collection.insert_one(data)

            print(
                f"{file} importé"
            )
# Out:
# rapport_json_chaine_froid.json importé
# rapport_json_distributeur.json importé
# rapport_json_entrepot_stockage.json importé
# rapport_json_fournisseur.json importé
# rapport_json_reglementaire.json importé
# rapport_json_systeme_qualite.json importé
# rapport_json_transport.json importé

# %%
collection = db["CAPA_reports"]

folder_path =  r"C:\Users\Lenovo\Desktop\QualiChainAI\Backend\docs\CAPA_rapports"

for file in os.listdir(folder_path):

    if file.endswith(".json"):

        path = os.path.join(folder_path, file)

        with open(
            path,
            "r",
            encoding="utf-8"
        ) as f:

            data = json.load(f)

            collection.insert_one(data)

            print(
                f"{file} importé"
            )
# Out:
# rapport_capa_chaine_froid.json importé
# rapport_capa_distributeur.json importé
# rapport_capa_entrepot_stockage.json importé
# rapport_capa_fournisseur.json importé
# rapport_capa_reglementaire.json importé
# rapport_capa_systeme_qualite.json importé
# rapport_capa_transport.json importé
